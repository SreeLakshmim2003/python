# %%
marks=[80,75,90,85,70]
print(marks[0])
# Out:
# 80

# %%
numbers=[1,2,3]
numbers.append(4)
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
numbers=(10,20,30,40,50)
print(numbers[2])
# Out:
# 30

# %%
numbers={1,2,2,3,3,4}
print(numbers)
# Out:
# {1, 2, 3, 4}

# %%
student={"name":"sree", "age":18, "mark":90}
(student["name"])
# Out:
# 'sree'

# %%
name="python"
print(name[0])
print(name[-1])
# Out:
# p
# n
